# %%
import cv2
from google.colab.patches import cv2_imshow

# Read image
img = cv2.imread("sample1.jpg")

# Convert to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Show images
cv2_imshow(img)
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=RGB size=426x236>
# <PIL.Image.Image image mode=L size=426x236>
