# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

img = cv2.imread("sample5.jpg", 0)

kernel = np.ones((5,5), np.uint8)
erode = cv2.erode(img, kernel, iterations=1)

cv2_imshow(img)
cv2_imshow(erode)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=233x241>
# <PIL.Image.Image image mode=L size=233x241>
